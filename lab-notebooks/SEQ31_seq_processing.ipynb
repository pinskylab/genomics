# %% [markdown]
# # Processing SEQ31
# Formerly called SEQ21 - this is one of the sequencing runs for APCL sent to Princeton in Fall 2018.
# ## Prepare the directories for sequence storage

# %%
# !mkdir /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31

# %% [markdown]
# ## Go to the Princeton webpage to retrieve the seq data - took about 5 minutes for SEQ29 - 576 samples
# https://htseq.princeton.edu/cgi-bin/login.pl?redirect_url=https://htseq.princeton.edu/cgi-bin/dashboard.pl
# * Click on the sequencing run of interest in the box on the left that says “Recently Entered Samples"
# * In the box titled Sample Provenance, click on the link following "This library was utilized within the following output(s):” - repeat for each lane
# * In the “Data and Statistics” box, in the bottom right corner is a green button that says “Download"
# * click wget and then the copy button to get all files.  This will copy the wget commands for all files.
# * paste in the cell below
# * repeat for the 2nd lane if necessary

# %%
# %%bash
# # started at 8:14am, finished before 8:19am
# cd /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31
# wget -nd https://htseq.princeton.edu/tmp/RoJdw929JSd7Z59j0/21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_barcodes.txt
# wget -nd https://htseq.princeton.edu/tmp/RoJdw929JSd7Z59j0/21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_1_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/RoJdw929JSd7Z59j0/21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/RoJdw929JSd7Z59j0/21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_3_Index_Read_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/RoJdw929JSd7Z59j0/md5sum.txt
#
# # test
# ls
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# %%bash
# # started at 8:20am
# cd /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31
# wget -nd https://htseq.princeton.edu/tmp/B7nmdL8hsnxINa1c7/21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_barcodes.txt
# wget -nd https://htseq.princeton.edu/tmp/B7nmdL8hsnxINa1c7/21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_Read_1_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/B7nmdL8hsnxINa1c7/21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_Read_2_Index_Read_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/B7nmdL8hsnxINa1c7/21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_Read_3_Index_Read_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/B7nmdL8hsnxINa1c7/md5sum.txt
#
# #test
# ls
# Out:
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_barcodes.txt
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_barcodes.txt.1
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_1_passed_filter.fastq.gz
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_1_passed_filter.fastq.gz.1
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz.1
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_3_Index_Read_passed_filter.fastq.gz
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_3_Index_Read_passed_filter.fastq.gz.1
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_barcodes.txt
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_Read_1_passed_filter.fastq.gz
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_Read_2_Index_Read_passed_filter.fastq.gz
# 21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_Read_3_Index_Read_passed_filter.fastq.gz
# md5sum.txt
# md5sum.txt.1
# md5sum.txt.2
# IOPub data rate exceeded.
# ...

# %% [markdown]
# ## Double downloaded lane 1, checked that the file sizes were the same, and deleted the duplicate:

# %%
# !ls -alh cd /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31
# Out:
# ls: cannot access cd: No such file or directory
# /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31:
# total 46G
# drwxrwxr-x.  2 michelles michelles  4.0K Oct  4 08:23 .
# drwxrwxr-x. 41 malinp    pinsky_lab 4.0K Oct  4 08:02 ..
# -rw-rw-r--.  1 michelles michelles    27 Oct  3 17:17 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_barcodes.txt
# -rw-rw-r--.  1 michelles michelles    27 Oct  3 15:48 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_barcodes.txt.1
# -rw-rw-r--.  1 michelles michelles   14G Oct  3 17:19 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_1_passed_filter.fastq.gz
# -rw-rw-r--.  1 michelles michelles   14G Oct  3 15:44 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_1_passed_filter.fastq.gz.1
# -rw-rw-r--.  1 michelles michelles  1.1G Oct  3 17:20 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz
# -rw-rw-r--.  1 michelles michelles  1.1G Oct  3 15:47 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz.1
# ...

# %%
# !rm /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31/*.gz.1

# %%
# !ls -alh cd /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31
# Out:
# ls: cannot access cd: No such file or directory
# /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31:
# total 31G
# drwxrwxr-x.  2 michelles michelles  4.0K Oct  4 08:28 .
# drwxrwxr-x. 41 malinp    pinsky_lab 4.0K Oct  4 08:02 ..
# -rw-rw-r--.  1 michelles michelles    27 Oct  3 17:17 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_barcodes.txt
# -rw-rw-r--.  1 michelles michelles    27 Oct  3 15:48 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_barcodes.txt.1
# -rw-rw-r--.  1 michelles michelles   14G Oct  3 17:19 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_1_passed_filter.fastq.gz
# -rw-rw-r--.  1 michelles michelles  1.1G Oct  3 17:20 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz
# -rw-rw-r--.  1 michelles michelles  659M Oct  3 17:20 21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_3_Index_Read_passed_filter.fastq.gz
# -rw-rw-r--.  1 michelles michelles    27 Oct  3 15:56 21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_barcodes.txt
# ...

# %% [markdown]
# ## Make directories in personal workspace - 12 pools in each seq
# These are already done for all of the fall 2018 seqs

# %%
#%%bash
#cd ~/02-apcl-ddocent
#mkdir 31seq
#cd ../31seq/ 
#mkdir bcsplit 01Pool 02Pool 03Pool 04Pool 05Pool 06Pool 07Pool 08Pool 09Pool 10Pool 11Pool 12Pool logs samples scripts
#cd bcsplit/
#mkdir lane1 lane2

# %% [markdown]
# ## Move index files and names files from laptop to amphiprion with Fetch
# ### see seq_proc.Rmd notebook in RStudio to generate index and names files for large batches of pools/samples

# %% [markdown]
# ## Copy barcodes files into each of the logs folders

# %%
#%%bash
#cd ~/02-apcl-ddocent
#cp 16seq/logs/barcodes 31seq/logs

# %% [markdown]
# ## Run barcode splitter in lane1 folder and lane 2 folder
# Have to run both commands from terminal because lane1 of seq30 is taking up the notebook folder output location currently.  Pasted these lines into terminal.
# Started at 8:43am on Thursday
# at 9:34am, only 3 python2's are running, one stopped when I closed the notebook.  Will be able to tell based on size or what hasn't updated since 9:30 once I get to work.

# %%
# %%bash
# cd ~/02-apcl-ddocent/31seq/bcsplit/lane1
# nohup /local/home/michelles/14_programs/paired_sequence_utils/barcode_splitter.py \
# --bcfile ../../logs/index-SEQ21.tsv \
# --idxread 2 --suffix .fastq.gz \
# /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31/21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_1_passed_filter.fastq.gz \
# /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31/21_APCL_Seq-for-196-cycles-HLJTKBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz &
# cd ~/02-apcl-ddocent/31seq/bcsplit/lane2
# /local/home/michelles/14_programs/paired_sequence_utils/barcode_splitter.py \
# --bcfile ../../logs/index-SEQ21.tsv \
# --idxread 2 --suffix .fastq.gz \
# /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31/21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_Read_1_passed_filter.fastq.gz \
# /local/shared/pinsky_lab/sequencing/hiseq_2018_10_03_SEQ31/21_APCL_Seq-for-196-cycles-HLJTKBCX2_2_Read_2_Index_Read_passed_filter.fastq.gz

# %% [markdown]
# ## Concatenate the results in the bcsplit folder - takes about 1 minute
# * For large batches, generated the command lines in a script in the seq_proc.Rmd notebook and output the lines into files called SEQXX_cat_all.sh to be copy and pasted here

# %%
# %%bash
# cat ./lane1/P117-read-1.fastq.gz ./lane2/P117-read-1.fastq.gz > ../01Pool/P117.fastq.gz
# cat ./lane1/P118-read-1.fastq.gz ./lane2/P118-read-1.fastq.gz > ../02Pool/P118.fastq.gz
# cat ./lane1/P119-read-1.fastq.gz ./lane2/P119-read-1.fastq.gz > ../03Pool/P119.fastq.gz
# cat ./lane1/P120-read-1.fastq.gz ./lane2/P120-read-1.fastq.gz > ../04Pool/P120.fastq.gz
# cat ./lane1/P121-read-1.fastq.gz ./lane2/P121-read-1.fastq.gz > ../05Pool/P121.fastq.gz
# cat ./lane1/P122-read-1.fastq.gz ./lane2/P122-read-1.fastq.gz > ../06Pool/P122.fastq.gz
# cat ./lane1/P123-read-1.fastq.gz ./lane2/P123-read-1.fastq.gz > ../07Pool/P123.fastq.gz
# cat ./lane1/P124-read-1.fastq.gz ./lane2/P124-read-1.fastq.gz > ../08Pool/P124.fastq.gz
# cat ./lane1/P125-read-1.fastq.gz ./lane2/P125-read-1.fastq.gz > ../09Pool/P125.fastq.gz
# cat ./lane1/P126-read-1.fastq.gz ./lane2/P126-read-1.fastq.gz > ../10Pool/P126.fastq.gz
# cat ./lane1/P127-read-1.fastq.gz ./lane2/P127-read-1.fastq.gz > ../11Pool/P127.fastq.gz
# cat ./lane1/P128-read-1.fastq.gz ./lane2/P128-read-1.fastq.gz > ../12Pool/P128.fastq.gz

# %%
# !ls 01Pool/
# Out:
# P117.fastq.gz	     sample_AGGAGA.fq.gz  sample_CGAATG.fq.gz
# process_radtags.log  sample_AGTAAG.fq.gz  sample_GACGTT.fq.gz
# sample_AAACAC.fq.gz  sample_AGTCCT.fq.gz  sample_GATACA.fq.gz
# sample_AAACGA.fq.gz  sample_AGTTAC.fq.gz  sample_GCAGAA.fq.gz
# sample_AAAGTC.fq.gz  sample_ATAACC.fq.gz  sample_GGGATA.fq.gz
# sample_AACGGT.fq.gz  sample_ATCGCA.fq.gz  sample_GGTGAA.fq.gz
# sample_AACTTC.fq.gz  sample_ATCTCG.fq.gz  sample_GTAGCT.fq.gz
# sample_AAGAAC.fq.gz  sample_ATGGAG.fq.gz  sample_GTCTAT.fq.gz
# sample_AATGTG.fq.gz  sample_ATGTCC.fq.gz  sample_GTTCAG.fq.gz
# sample_ACATGT.fq.gz  sample_CAATTG.fq.gz  sample_TAAGAC.fq.gz
# sample_ACCAAA.fq.gz  sample_CAGAGT.fq.gz  sample_TACCAG.fq.gz
# sample_ACGATA.fq.gz  sample_CATCAG.fq.gz  sample_TCAATC.fq.gz
# sample_ACGTTT.fq.gz  sample_CATCTC.fq.gz  sample_TCCAAA.fq.gz
# sample_ACTAGG.fq.gz  sample_CCACTT.fq.gz  sample_TCTGCT.fq.gz
# sample_ACTCCA.fq.gz  sample_CCCATA.fq.gz  sample_TCTTAG.fq.gz
# ...

# %% [markdown]
# ## Run process_radtags scripts  - takes several hours
# * Created process_radtags scripts with the seq_proc.Rmd notebook and then moved the files with fetch to amphiprion in the 29seq/scripts folder.
# * In fetch, also highlighted the scripts, clicked get info, and then checked "execute" instead of having to chmod u+x for all of them.
# * Also wrote a script to generate the command lines to run process rad tags.
# * The command lines are in the files SEQXX_process_all.sh
#
#
# * Started at 3:30pm on Friday night for SEQ31.
# * If this notebook closes, these processes stop - **ended up pasting this into a terminal window** because I was afraid the network would drop and the process would stop

# %% [markdown]
# cd ~/02-apcl-ddocent/31seq/
# nohup ./scripts/P117_process.sh &
# nohup ./scripts/P118_process.sh &
# nohup ./scripts/P119_process.sh &
# nohup ./scripts/P120_process.sh &
# nohup ./scripts/P121_process.sh &
# nohup ./scripts/P122_process.sh &
# nohup ./scripts/P123_process.sh &
# nohup ./scripts/P124_process.sh &
# nohup ./scripts/P125_process.sh &
# nohup ./scripts/P126_process.sh &
# nohup ./scripts/P127_process.sh &
# nohup ./scripts/P128_process.sh &

# %% [markdown]
# ## Move the process_radtags logs to the logs folder.
# Wrote command lines for large batches in seq_proc.Rmd notebook and saved the lines in files called SEQXX-move_radlogs.sh

# %%
# %%bash
# mv 01Pool/process_radtags.log ./logs/processP117.log
# mv 02Pool/process_radtags.log ./logs/processP118.log
# mv 03Pool/process_radtags.log ./logs/processP119.log
# mv 04Pool/process_radtags.log ./logs/processP120.log
# mv 05Pool/process_radtags.log ./logs/processP121.log
# mv 06Pool/process_radtags.log ./logs/processP122.log
# mv 07Pool/process_radtags.log ./logs/processP123.log
# mv 08Pool/process_radtags.log ./logs/processP124.log
# mv 09Pool/process_radtags.log ./logs/processP125.log
# mv 10Pool/process_radtags.log ./logs/processP126.log
# mv 11Pool/process_radtags.log ./logs/processP127.log
# mv 12Pool/process_radtags.log ./logs/processP128.log

# %% [markdown]
# ## Run the readprocesslog.py script
# to convert the process log into a tsv that can be imported into the database through R.

# %%
# %%bash
# readprocesslog.py ./logs/processP117.log
# readprocesslog.py ./logs/processP118.log
# readprocesslog.py ./logs/processP119.log
# readprocesslog.py ./logs/processP120.log
# readprocesslog.py ./logs/processP121.log
# readprocesslog.py ./logs/processP122.log
# readprocesslog.py ./logs/processP123.log
# readprocesslog.py ./logs/processP124.log
# readprocesslog.py ./logs/processP125.log
# readprocesslog.py ./logs/processP126.log
# readprocesslog.py ./logs/processP127.log
# readprocesslog.py ./logs/processP128.log
# Out:
# AAACAC	171136	2392	7188	160784
# AAACGA	136500	1542	5740	128592
# AAAGTC	149771	787	5879	142319
# AACGGT	156663	1004	6064	148853
# AACTTC	105903	931	4814	99617
# TGCTCA	127311	1070	5230	120341
# AAGAAC	78668	679	3945	73693
# AATGTG	5239	920	218	4076
# ACATGT	111300	3487	4462	102854
# ACCAAA	82461	563	3702	77796
# ACGATA	86502	692	4204	81179
# ACGTTT	104115	1085	4520	98061
# ACTAGG	91031	600	3607	86405
# ACTCCA	3967	153	219	3573
# AGACTC	140657	580	5627	133793
# AGCATT	127638	1620	6105	119297
# AGGAGA	90095	642	3689	85328
# AGTAAG	96453	865	4720	90395
# AGTCCT	91383	924	4069	85962
# AGTTAC	130219	597	5136	123856
# ATAACC	118575	803	5347	111901
# ATCGCA	147573	603	6186	140093
# ATCTCG	134426	621	5742	127455
# ATGGAG	175952	901	7213	166965
# ATGTCC	134184	609	5033	127929
# CAATTG	220656	7922	8111	203633
# CAGAGT	2182	114	154	1905
# CATCAG	104424	2290	4237	97415
# CATCTC	94567	399	3416	90289
# CCACTT	122742	668	4830	116639
# CCCATA	128820	1274	5517	121366
# CCTGAA	117060	570	5391	110551
# ...

# %% [markdown]
# ## Move the newly created tsvs to the laptop with fetch and import them into the database using the script reads_to_db.Rmd

# %% [markdown]
# ## Rename the sample files
# * used script in seq_proc.Rmd to generate mass command line text stored in SEQXX_all_rename.sh
# * Used text editor to change the move location to the samples folder in /data instead of in home/michelles

# %%
# %%bash
# cd 01Pool/
# sh rename.for.dDocent_se_gz ../logs/names_117.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 02Pool/
# sh rename.for.dDocent_se_gz ../logs/names_118.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 03Pool/
# sh rename.for.dDocent_se_gz ../logs/names_119.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 04Pool/
# sh rename.for.dDocent_se_gz ../logs/names_120.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 05Pool/
# sh rename.for.dDocent_se_gz ../logs/names_121.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 06Pool/
# sh rename.for.dDocent_se_gz ../logs/names_122.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 07Pool/
# sh rename.for.dDocent_se_gz ../logs/names_123.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 08Pool/
# sh rename.for.dDocent_se_gz ../logs/names_124.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 09Pool/
# sh rename.for.dDocent_se_gz ../logs/names_125.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 10Pool/
# sh rename.for.dDocent_se_gz ../logs/names_126.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 11Pool/
# sh rename.for.dDocent_se_gz ../logs/names_127.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 12Pool/
# sh rename.for.dDocent_se_gz ../logs/names_128.tsv
# mv APCL* /data/apcl/31seq/samples
# cd ..
# Out:
# APCL_L4120.F
# AAACAC
# APCL_L4168.F
# AAACAC
# APCL_L4216.F
# AAACAC
# APCL_L4264.F
# AAACAC
# APCL_L4312.F
# AAACAC
# APCL_L4360.F
# AAACAC
# APCL_L4504.F
# AAACAC
# APCL_L4552.F
# AAACAC
# APCL_L4600.F
# AAACAC
# APCL_L4648.F
# AAACAC
# APCL_L4696.F
# AAACAC
# APCL_L4754.F
# AAACAC
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory
# mv: target `/data/apcl/31seq/samples' is not a directory

# %%
# !mkdir /data/apcl/31seq/samples

# %%
# %%bash
# cd 01Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 02Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 03Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 04Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 05Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 06Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 07Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 08Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 09Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 10Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 11Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..
# cd 12Pool/
#
# mv APCL* /data/apcl/31seq/samples
# cd ..

# %% [markdown]
# ## Once all of the samples have been moved, move the gz files to the logs and then you can delete the pool directories

# %%
# !rm -r *Pool

# %% [markdown]
# ## Identify regenotyped samples, cat and move them.

# %%
# !mkdir /data/apcl/31seq/samples/regenos

# %% [markdown]
# ### Make a table of all of the regenotyped samples
# * in the R notebook cat_regenos.Rmd.
# * in text editor, find and replace the files coming from seq30 to include the extra F in the names, used the regex
# find: (30seq/samples/APCL_L\d+)(.F).fq.gz
# replace: \1\2.F.fq.gz
# * Changed the R script so that the output file is named in dDocent format and the cat'd output file is kept with the current seq sample population.
# * Generate command lines to paste here.

# %%
# !ls /data/apcl/31seq/samples
# Out:
# APCL_L4120.F.F.fq.gz  APCL_L4313.F.F.fq.gz  APCL_L4602.F.F.fq.gz
# APCL_L4121.F.F.fq.gz  APCL_L4314.F.F.fq.gz  APCL_L4603.F.F.fq.gz
# APCL_L4122.F.F.fq.gz  APCL_L4315.F.F.fq.gz  APCL_L4604.F.F.fq.gz
# APCL_L4123.F.F.fq.gz  APCL_L4316.F.F.fq.gz  APCL_L4605.F.F.fq.gz
# APCL_L4124.F.F.fq.gz  APCL_L4317.F.F.fq.gz  APCL_L4606.F.F.fq.gz
# APCL_L4125.F.F.fq.gz  APCL_L4318.F.F.fq.gz  APCL_L4607.F.F.fq.gz
# APCL_L4126.F.F.fq.gz  APCL_L4319.F.F.fq.gz  APCL_L4608.F.F.fq.gz
# APCL_L4127.F.F.fq.gz  APCL_L4320.F.F.fq.gz  APCL_L4609.F.F.fq.gz
# APCL_L4128.F.F.fq.gz  APCL_L4321.F.F.fq.gz  APCL_L4610.F.F.fq.gz
# APCL_L4129.F.F.fq.gz  APCL_L4322.F.F.fq.gz  APCL_L4611.F.F.fq.gz
# APCL_L4130.F.F.fq.gz  APCL_L4323.F.F.fq.gz  APCL_L4612.F.F.fq.gz
# APCL_L4131.F.F.fq.gz  APCL_L4324.F.F.fq.gz  APCL_L4613.F.F.fq.gz
# APCL_L4132.F.F.fq.gz  APCL_L4325.F.F.fq.gz  APCL_L4614.F.F.fq.gz
# APCL_L4133.F.F.fq.gz  APCL_L4326.F.F.fq.gz  APCL_L4615.F.F.fq.gz
# ...

# %%
# %%bash
# #!/bin/bash
# cat /data/apcl/13seq/samples/APCL_L2412.F.fq.gz /data/apcl/31seq/samples/APCL_L4264.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L2412.L4264.F.fq.gz
# cat /data/apcl/12seq/samples/APCL_L2271.F.fq.gz /data/apcl/31seq/samples/APCL_L4265.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L2271.L4265.F.fq.gz
# cat /data/apcl/12seq/samples/APCL_L2280.F.fq.gz /data/apcl/31seq/samples/APCL_L4266.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L2280.L4266.F.fq.gz
# cat /data/apcl/03seq/samples/APCL_L0281.F.fq.gz /data/apcl/31seq/samples/APCL_L4504.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0281.L4504.F.fq.gz
# cat /data/apcl/03seq/samples/APCL_L0304.F.fq.gz /data/apcl/31seq/samples/APCL_L4276.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0304.L4276.F.fq.gz
# cat /data/apcl/03seq/samples/APCL_L0305.F.fq.gz /data/apcl/31seq/samples/APCL_L4274.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0305.L4274.F.fq.gz
# cat /data/apcl/04seq/samples/APCL_L0640.F.fq.gz /data/apcl/31seq/samples/APCL_L4711.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0640.L4711.F.fq.gz
# cat /data/apcl/03seq/samples/APCL_L0337.F.fq.gz /data/apcl/31seq/samples/APCL_L4216.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0337.L4216.F.fq.gz
# cat /data/apcl/04seq/samples/APCL_L0645.F.fq.gz /data/apcl/31seq/samples/APCL_L4547.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0645.L4547.F.fq.gz
# cat /data/apcl/04seq/samples/APCL_L0647.F.fq.gz /data/apcl/31seq/samples/APCL_L4712.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0647.L4712.F.fq.gz
# cat /data/apcl/05seq/samples/APCL_L0859.F.fq.gz /data/apcl/28seq/samples/APCL_L3218.F.fq.gz /data/apcl/31seq/samples/APCL_L4360.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0859.L3218.L4360.F.fq.gz
# cat /data/apcl/13seq/samples/APCL_L2533.F.fq.gz /data/apcl/31seq/samples/APCL_L4168.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L2533.L4168.F.fq.gz
# cat /data/apcl/17seq/samples/APCL_L3089.F.fq.gz /data/apcl/31seq/samples/APCL_L4553.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3089.L4553.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3178.F.fq.gz /data/apcl/31seq/samples/APCL_L4169.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3178.L4169.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3182.F.fq.gz /data/apcl/31seq/samples/APCL_L4754.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3182.L4754.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3185.F.fq.gz /data/apcl/31seq/samples/APCL_L4755.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3185.L4755.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3188.F.fq.gz /data/apcl/31seq/samples/APCL_L4361.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3188.L4361.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3191.F.fq.gz /data/apcl/31seq/samples/APCL_L4648.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3191.L4648.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3193.F.fq.gz /data/apcl/31seq/samples/APCL_L4756.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3193.L4756.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3196.F.fq.gz /data/apcl/31seq/samples/APCL_L4170.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3196.L4170.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3199.F.fq.gz /data/apcl/31seq/samples/APCL_L4362.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3199.L4362.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3200.F.fq.gz /data/apcl/31seq/samples/APCL_L4757.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3200.L4757.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3208.F.fq.gz /data/apcl/31seq/samples/APCL_L4171.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3208.L4171.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3210.F.fq.gz /data/apcl/31seq/samples/APCL_L4172.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3210.L4172.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3215.F.fq.gz /data/apcl/31seq/samples/APCL_L4758.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3215.L4758.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3217.F.fq.gz /data/apcl/31seq/samples/APCL_L4173.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3217.L4173.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3738.F.fq.gz /data/apcl/31seq/samples/APCL_L4520.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3738.L4520.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3735.F.fq.gz /data/apcl/31seq/samples/APCL_L4686.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3735.L4686.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3705.F.fq.gz /data/apcl/31seq/samples/APCL_L4521.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3705.L4521.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3265.F.fq.gz /data/apcl/31seq/samples/APCL_L4528.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3265.L4528.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3262.F.fq.gz /data/apcl/31seq/samples/APCL_L4695.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3262.L4695.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3261.F.fq.gz /data/apcl/31seq/samples/APCL_L4718.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3261.L4718.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3259.F.fq.gz /data/apcl/31seq/samples/APCL_L4258.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3259.L4258.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3258.F.fq.gz /data/apcl/31seq/samples/APCL_L4529.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3258.L4529.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3257.F.fq.gz /data/apcl/31seq/samples/APCL_L4530.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3257.L4530.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3256.F.fq.gz /data/apcl/31seq/samples/APCL_L4719.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3256.L4719.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3255.F.fq.gz /data/apcl/31seq/samples/APCL_L4720.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3255.L4720.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3252.F.fq.gz /data/apcl/31seq/samples/APCL_L4259.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3252.L4259.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3251.F.fq.gz /data/apcl/31seq/samples/APCL_L4531.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3251.L4531.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3250.F.fq.gz /data/apcl/31seq/samples/APCL_L4696.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3250.L4696.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3249.F.fq.gz /data/apcl/31seq/samples/APCL_L4721.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3249.L4721.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3248.F.fq.gz /data/apcl/31seq/samples/APCL_L4697.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3248.L4697.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3245.F.fq.gz /data/apcl/31seq/samples/APCL_L4722.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3245.L4722.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3239.F.fq.gz /data/apcl/31seq/samples/APCL_L4698.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3239.L4698.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3238.F.fq.gz /data/apcl/31seq/samples/APCL_L4260.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3238.L4260.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3237.F.fq.gz /data/apcl/31seq/samples/APCL_L4699.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3237.L4699.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3234.F.fq.gz /data/apcl/31seq/samples/APCL_L4261.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3234.L4261.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3233.F.fq.gz /data/apcl/31seq/samples/APCL_L4700.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3233.L4700.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3232.F.fq.gz /data/apcl/31seq/samples/APCL_L4723.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3232.L4723.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3230.F.fq.gz /data/apcl/31seq/samples/APCL_L4532.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3230.L4532.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3228.F.fq.gz /data/apcl/31seq/samples/APCL_L4701.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3228.L4701.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3227.F.fq.gz /data/apcl/31seq/samples/APCL_L4262.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3227.L4262.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3223.F.fq.gz /data/apcl/31seq/samples/APCL_L4533.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3223.L4533.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3221.F.fq.gz /data/apcl/31seq/samples/APCL_L4534.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3221.L4534.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3219.F.fq.gz /data/apcl/31seq/samples/APCL_L4263.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3219.L4263.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3688.F.fq.gz /data/apcl/31seq/samples/APCL_L4190.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3688.L4190.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3689.F.fq.gz /data/apcl/31seq/samples/APCL_L4384.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3689.L4384.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3692.F.fq.gz /data/apcl/31seq/samples/APCL_L4659.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3692.L4659.F.fq.gz
# cat /data/apcl/28seq/samples/APCL_L3696.F.fq.gz /data/apcl/31seq/samples/APCL_L4767.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L3696.L4767.F.fq.gz
# Out:
# cat: /data/apcl/05seq/samples/APCL_L0859.F.fq.gz: No such file or directory
# cat: /data/apcl/28seq/samples/APCL_L3218.F.fq.gz: No such file or directory

# %%
# !cat /data/apcl/05seq/samples/regenos/APCL_L0859.F.fq.gz /data/apcl/28seq/samples/regenos/APCL_L3218.F.fq.gz /data/apcl/31seq/samples/APCL_L4360.F.F.fq.gz > /data/apcl/31seq/samples/APCL_L0859.L3218.L4360.F.fq.gz

# %% [markdown]
# ## Move the regenotyped samples to regeno folders

# %%
# %%bash
# mv /data/apcl/13seq/samples/APCL_L2412* /data/apcl/13seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4264* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/12seq/samples/APCL_L2271* /data/apcl/12seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4265* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/12seq/samples/APCL_L2280* /data/apcl/12seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4266* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/03seq/samples/APCL_L0281* /data/apcl/03seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4504* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/03seq/samples/APCL_L0304* /data/apcl/03seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4276* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/03seq/samples/APCL_L0305* /data/apcl/03seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4274* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/04seq/samples/APCL_L0640* /data/apcl/04seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4711* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/03seq/samples/APCL_L0337* /data/apcl/03seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4216* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/04seq/samples/APCL_L0645* /data/apcl/04seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4547* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/04seq/samples/APCL_L0647* /data/apcl/04seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4712* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/05seq/samples/APCL_L0859* /data/apcl/05seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3218* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4360* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/13seq/samples/APCL_L2533* /data/apcl/13seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4168* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/17seq/samples/APCL_L3089* /data/apcl/17seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4553* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3178* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4169* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3182* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4754* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3185* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4755* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3188* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4361* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3191* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4648* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3193* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4756* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3196* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4170* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3199* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4362* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3200* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4757* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3208* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4171* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3210* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4172* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3215* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4758* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3217* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4173* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3738* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4520* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3735* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4686* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3705* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4521* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3265* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4528* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3262* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4695* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3261* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4718* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3259* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4258* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3258* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4529* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3257* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4530* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3256* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4719* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3255* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4720* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3252* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4259* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3251* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4531* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3250* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4696* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3249* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4721* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3248* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4697* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3245* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4722* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3239* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4698* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3238* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4260* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3237* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4699* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3234* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4261* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3233* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4700* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3232* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4723* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3230* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4532* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3228* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4701* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3227* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4262* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3223* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4533* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3221* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4534* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3219* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4263* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3688* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4190* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3689* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4384* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3692* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4659* /data/apcl/31seq/samples/regenos/
# mv /data/apcl/28seq/samples/APCL_L3696* /data/apcl/28seq/samples/regenos/
# mv /data/apcl/31seq/samples/APCL_L4767* /data/apcl/31seq/samples/regenos/
# Out:
# mv: cannot stat `/data/apcl/05seq/samples/APCL_L0859*': No such file or directory
# mv: cannot stat `/data/apcl/28seq/samples/APCL_L3218*': No such file or directory

# %% [markdown]
# Those files are already in the regenos folders.

# %% [markdown]
# ## Copy reference.fasta over from jonsfiles

# %%
# !cp /local/home/michelles/02-apcl-ddocent/jonsfiles/reference.fasta /data/apcl/31seq/samples

# %% [markdown]
# ## Trim, map , and call SNPs using dDocent
# for this phase, dDocent will ask questions.
#
# * Are the number of samples correct?
#
# yes  S
#
# * Maximum number of processors to use for this analysis
#
# This depends on how many people are trying to use amphiprion right now.  The trim and map section isn't too intensive so it should be ok to use alot.  I used 30 for SEQ18 - 576 samples
#
# 30
#
# * Maximum memory
#
# Again, consider who else is using the machine, for SEQ18 - 576 samples I used 150
#
# 150
#
# * Quality trim?
#
# yes
#
# * Perform assembly?
#
# no - this is for creating the reference originally
#
# * Map reads?
#
# yes
#
# * Adjust default parameters
#
# default match score is 1, default mismatch is 4, gap penalty is 6 - I used defaults for all
#
# * call SNPs
#
# yes
#
# * enter email address to be notified when it is done running

# %% [markdown]
# ## dDocent stopped mid run
# * Plenty of space on /data
# * 9.8 out of 16T used
# * maybe stopped because I was running SEQ30 ddocent at the same time with 30 processors and 150 memory.
# * tried again, got the following message
# * can't move notebook to /data/apcl/31seq/samples, running from here

# %%
# %%bash
# cd /data/apcl/31seq/samples
# dDocent
# Out:
# dDocent 2.5.5
#
# Contact jpuritz@uri.edu with any problems
#
#
# Checking for required software
#
# All required software is installed!
# Individuals do not follow the dDocent naming convention.
# Please rename individuals to: Locality_Individual.F.fq.gz
# For example: LocA_001.F.fq.gz
# /local/home/michelles/14_programs/dDocent/dDocent: line 84: [: 1.0-r82: integer expression expected
# sed: couldn't open temporary file ./sedCppjnv: No space left on device

# %% [markdown]
# ### create a temporary directory and move all of the files that don't fit the naming convention to that directory, then move reference.fasta back into the main samples directory.

# %%
# %%bash
# cd /data/apcl/31seq/samples
# mkdir second_attempt
# mv *.F.fq.gz second_attempt/
# mv reference.fasta second_attempt/

# %% [markdown]
# ### Waiting for space issues to be resolved.

# %%
# %%bash
# cd /data/apcl/31seq/samples/second_attempt/
# dDocent
# Out:
# dDocent 2.5.5
#
# Contact jpuritz@uri.edu with any problems
#
#
# Checking for required software
#
# All required software is installed!
#
# dDocent run started Sun Oct 7 13:03:59 EDT 2018
#
# 576 individuals are detected. Is this correct? Enter yes or no and press [ENTER]
# Incorrect Input
# /local/home/michelles/14_programs/dDocent/dDocent: line 84: [: 1.0-r82: integer expression expected

# %% [markdown]
# ## Re-started dDocent in second_attempt folder at 1pm on Sunday 10/7/2018

# %% [markdown]
# dDocent has finished with an analysis in /data/apcl/31seq/samples/second_attempt
#
# dDocent started Sun Oct 7 13:04:28 EDT 2018
#
# dDocent finished Sun Oct 7 22:28:54 EDT 2018
#
#  After filtering, kept 17640 out of a possible 384455 Sites
#
# dDocent 2.5.5

# %% [markdown]
# ## Combine the total raw snps with all samples and continue from there
