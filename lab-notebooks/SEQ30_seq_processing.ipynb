# %% [markdown]
# # Processing SEQ30
# Formerly called SEQ20 - this is one of the sequencing runs for APCL sent to Princeton in Fall 2018.
# ## Prepare the directories for sequence storage

# %%
# !mkdir /local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30

# %% [markdown]
# ## Go to the Princeton webpage to retrieve the seq data - took about 5 minutes for SEQ29 - 576 samples
# https://htseq.princeton.edu/cgi-bin/login.pl?redirect_url=https://htseq.princeton.edu/cgi-bin/dashboard.pl
# * Click on the sequencing run of interest in the box on the left that says “Recently Entered Samples"
# * In the box titled Sample Provenance, click on the link following "This library was utilized within the following output(s):” - repeat for each lane
# * In the “Data and Statistics” box, in the bottom right corner is a green button that says “Download"
# * click wget and then the copy button to get all files.  This will copy the wget commands for all files.
# * paste in the cell below
# * repeat for the 2nd lane if necessary

# %%
# %%bash
# cd /local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30
# wget -nd https://htseq.princeton.edu/tmp/sH6s2yZj0NGDpZQi0/20_APCL_Seq-for-196-cycles-HLJNWBCX2_1_barcodes.txt
# wget -nd https://htseq.princeton.edu/tmp/sH6s2yZj0NGDpZQi0/20_APCL_Seq-for-196-cycles-HLJNWBCX2_1_Read_1_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/sH6s2yZj0NGDpZQi0/20_APCL_Seq-for-196-cycles-HLJNWBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/sH6s2yZj0NGDpZQi0/20_APCL_Seq-for-196-cycles-HLJNWBCX2_1_Read_3_Index_Read_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/sH6s2yZj0NGDpZQi0/md5sum.txt
#
# #test
# ls /local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30

# %%
# %%bash
# # started at 8:11am, finished by 8:14am
# cd /local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30
# wget -nd https://htseq.princeton.edu/tmp/XJ3AoTCcxlqhsZne2/20_APCL_Seq-for-196-cycles-HLJNWBCX2_2_barcodes.txt
# wget -nd https://htseq.princeton.edu/tmp/XJ3AoTCcxlqhsZne2/20_APCL_Seq-for-196-cycles-HLJNWBCX2_2_Read_1_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/XJ3AoTCcxlqhsZne2/20_APCL_Seq-for-196-cycles-HLJNWBCX2_2_Read_2_Index_Read_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/XJ3AoTCcxlqhsZne2/20_APCL_Seq-for-196-cycles-HLJNWBCX2_2_Read_3_Index_Read_passed_filter.fastq.gz
# wget -nd https://htseq.princeton.edu/tmp/XJ3AoTCcxlqhsZne2/md5sum.txt
#
# #test
# ls /local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30

# %% [markdown]
# ## Make directories in personal workspace - 12 pools in each seq
# These are already done for all of the fall 2018 seqs

# %%
#%%bash
#cd ~/02-apcl-ddocent
#mkdir 29seq
#cd ../29seq/ 
#mkdir bcsplit 01Pool 02Pool 03Pool 04Pool 05Pool 06Pool 07Pool 08Pool 09Pool 10Pool 11Pool 12Pool logs samples scripts
#cd bcsplit/
#mkdir lane1 lane2

# %% [markdown]
# ## Move index files and names files from laptop to amphiprion with Fetch
# ### see seq_proc.Rmd notebook in RStudio to generate index and names files for large batches of pools/samples

# %%
# !ls ~/02-apcl-ddocent/30seq/logs

# %%
# !mv /local/home/michelles/02-apcl-ddocent/30seq/logs/index-SEQ20.tsv \
/local/home/michelles/02-apcl-ddocent/30seq/logs/index-seq30.tsv

# %% [markdown]
# ## Copy barcodes files into the logs folders
# Already done while waiting for sequences to arrive

# %%
#%%bash
#cd ~/02-apcl-ddocent
#cp 16seq/logs/barcodes 30seq/logs

# %% [markdown]
# ## Run barcode splitter in lane1 folder and lane 2 folder
# Closing the notebook stops the process, even if it says nohup. To avoid this, run first lane from notebook (will put output in notebook folder), run second lane from terminal or wait until the first lane finishes.
#
# Takes about 10 hours for 576 samples
# Started at 8:38am on Thursday
# at 9:34am, only 3 python2's are running, one stopped when I closed the notebook.  Will be able to tell based on size or what hasn't updated since 9:30 once I get to work.
#     Looks like SEQ30 lane1 quit early.  restarting from the 30seq/bcsplit/lane1 directory at 2:23pm on Thursday - pasting in to terminal.

# %%
# original code
#%%bash
#cd /local/home/michelles/02-apcl-ddocent/30seq/bcsplit/lane1
#nohup /local/home/michelles/14_programs/paired_sequence_utils/barcode_splitter.py \
#--bcfile ../../logs/index-seq30.tsv --idxread 2 --suffix .fastq.gz \
#/local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30/20_APCL_Seq-for-196-cycles-HLJNWBCX2_1_Read_1_passed_filter.fastq.gz \
#/local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30/20_APCL_Seq-for-196-cycles-HLJNWBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz &
#cd /local/home/michelles/02-apcl-ddocent/30seq/bcsplit/lane2
#nohup /local/home/michelles/14_programs/paired_sequence_utils/barcode_splitter.py \
#--bcfile ../../logs/index-seq30.tsv --idxread 2 --suffix .fastq.gz \
#/local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30/20_APCL_Seq-for-196-cycles-HLJNWBCX2_2_Read_1_passed_filter.fastq.gz \
#/local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30/20_APCL_Seq-for-196-cycles-HLJNWBCX2_2_Read_2_Index_Read_passed_filter.fastq.gz &

# %%
# test code will output into notebook folder
# !nohup /local/home/michelles/14_programs/paired_sequence_utils/barcode_splitter.py \
--bcfile ../../logs/index-seq30.tsv --idxread 2 --suffix .fastq.gz \
/local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30/20_APCL_Seq-for-196-cycles-HLJNWBCX2_1_Read_1_passed_filter.fastq.gz \
/local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30/20_APCL_Seq-for-196-cycles-HLJNWBCX2_1_Read_2_Index_Read_passed_filter.fastq.gz &

# %% [markdown]
# Ran the following lines in terminal starting at 8:40am on Thursday

# %% [markdown]
# cd /local/home/michelles/02-apcl-ddocent/30seq/bcsplit/lane2
# nohup /local/home/michelles/14_programs/paired_sequence_utils/barcode_splitter.py \
# --bcfile ../../logs/index-seq30.tsv --idxread 2 --suffix .fastq.gz \
# /local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30/20_APCL_Seq-for-196-cycles-HLJNWBCX2_2_Read_1_passed_filter.fastq.gz \
# /local/shared/pinsky_lab/sequencing/hiseq_2018_10_04_SEQ30/20_APCL_Seq-for-196-cycles-HLJNWBCX2_2_Read_2_Index_Read_passed_filter.fastq.gz &

# %% [markdown]
# ## Concatenate the results in the bcsplit folder (with the notebook in the bcsplit folder)
# - takes about 1 minute
#
# For large batches, generated the command lines in a script in the seq_proc.Rmd notebook and output the lines into files called SEQXX_cat_all.sh to be copy and pasted here

# %%
# %%bash
# cat ./lane1/P103-read-1.fastq.gz ./lane2/P103-read-1.fastq.gz > ../01Pool/P103.fastq.gz
# cat ./lane1/P104-read-1.fastq.gz ./lane2/P104-read-1.fastq.gz > ../02Pool/P104.fastq.gz
# cat ./lane1/P107-read-1.fastq.gz ./lane2/P107-read-1.fastq.gz > ../03Pool/P107.fastq.gz
# cat ./lane1/P108-read-1.fastq.gz ./lane2/P108-read-1.fastq.gz > ../04Pool/P108.fastq.gz
# cat ./lane1/P109-read-1.fastq.gz ./lane2/P109-read-1.fastq.gz > ../05Pool/P109.fastq.gz
# cat ./lane1/P110-read-1.fastq.gz ./lane2/P110-read-1.fastq.gz > ../06Pool/P110.fastq.gz
# cat ./lane1/P111-read-1.fastq.gz ./lane2/P111-read-1.fastq.gz > ../07Pool/P111.fastq.gz
# cat ./lane1/P112-read-1.fastq.gz ./lane2/P112-read-1.fastq.gz > ../08Pool/P112.fastq.gz
# cat ./lane1/P113-read-1.fastq.gz ./lane2/P113-read-1.fastq.gz > ../09Pool/P113.fastq.gz
# cat ./lane1/P114-read-1.fastq.gz ./lane2/P114-read-1.fastq.gz > ../10Pool/P114.fastq.gz
# cat ./lane1/P115-read-1.fastq.gz ./lane2/P115-read-1.fastq.gz > ../11Pool/P115.fastq.gz
# cat ./lane1/P116-read-1.fastq.gz ./lane2/P116-read-1.fastq.gz > ../12Pool/P116.fastq.gz

# %% [markdown]
# ## Run process_radtags scripts  -  run in the SEQ directory - takes several hours
# * Created process_radtags scripts with the seq_proc.Rmd notebook and then moved the files with fetch to amphiprion in the 30seq/scripts folder.
# * In fetch, also highlighted the scripts, clicked get info, and then checked "execute" instead of having to chmod u+x for all of them.
# * Also wrote a script to generate the command lines to run process rad tags.
# * The command lines are in the files SEQXX_process_all.sh
#
#
# * Started at 3:15pm on Friday for SEQ30.
# * If this notebook closes, these processes stop - **ended up pasting this into a terminal window** because I was afraid the network would drop and the process would stop

# %% [markdown]
# nohup ./scripts/P103_process.sh &
# nohup ./scripts/P104_process.sh &
# nohup ./scripts/P107_process.sh &
# nohup ./scripts/P108_process.sh &
# nohup ./scripts/P109_process.sh &
# nohup ./scripts/P110_process.sh &
# nohup ./scripts/P111_process.sh &
# nohup ./scripts/P112_process.sh &
# nohup ./scripts/P113_process.sh &
# nohup ./scripts/P114_process.sh &
# nohup ./scripts/P115_process.sh &
# nohup ./scripts/P116_process.sh &

# %% [markdown]
# ## Move the process_radtags logs to the logs folder - wrote command lines for large batches in seq_proc.Rmd notebook and saved the lines in files called SEQXX-move_radlogs.sh

# %%
# %%bash
# mv /local/home/michelles/02-apcl-ddocent/30seq/nohup.out /local/home/michelles/02-apcl-ddocent/30seq/logs/process_nohup.out
# mv 01Pool/process_radtags.log ./logs/processP103.log
# mv 02Pool/process_radtags.log ./logs/processP104.log
# mv 03Pool/process_radtags.log ./logs/processP107.log
# mv 04Pool/process_radtags.log ./logs/processP108.log
# mv 05Pool/process_radtags.log ./logs/processP109.log
# mv 06Pool/process_radtags.log ./logs/processP110.log
# mv 07Pool/process_radtags.log ./logs/processP111.log
# mv 08Pool/process_radtags.log ./logs/processP112.log
# mv 09Pool/process_radtags.log ./logs/processP113.log
# mv 10Pool/process_radtags.log ./logs/processP114.log
# mv 11Pool/process_radtags.log ./logs/processP115.log
# mv 12Pool/process_radtags.log ./logs/processP116.log

# %% [markdown]
# ## Run the readprocesslog.py script
# to convert the process log into a tsv that can be imported into the database through R.
# *notebook should be in the 30seq directory, so changing directory should not be necessary*

# %%
# %%bash
# #cd ~/02-apcl-ddocent/30seq/
# readprocesslog.py ./logs/processP103.log
# readprocesslog.py ./logs/processP104.log
# readprocesslog.py ./logs/processP107.log
# readprocesslog.py ./logs/processP108.log
# readprocesslog.py ./logs/processP109.log
# readprocesslog.py ./logs/processP110.log
# readprocesslog.py ./logs/processP111.log
# readprocesslog.py ./logs/processP112.log
# readprocesslog.py ./logs/processP113.log
# readprocesslog.py ./logs/processP114.log
# readprocesslog.py ./logs/processP115.log
# readprocesslog.py ./logs/processP116.log
# Out:
# AAACAC	45648	1093	1519	42814
# AAACGA	379139	2193	10698	364155
# AAAGTC	385800	1310	10786	371546
# AACGGT	268892	1531	9812	256116
# AACTTC	445380	1740	14155	427133
# TGCTCA	569466	2498	15596	548398
# AAGAAC	330905	6935	18915	303510
# AATGTG	439479	10340	14771	412194
# ACATGT	481925	22474	17943	439219
# ACCAAA	634559	5225	20279	605784
# ACGATA	507240	3295	16158	485116
# ACGTTT	479754	6555	17777	452976
# ACTAGG	432303	3938	14276	411966
# ACTCCA	435240	4845	14771	413491
# AGACTC	393017	3788	15095	372129
# AGCATT	476896	6332	17000	451228
# AGGAGA	637145	3619	16478	613744
# AGTAAG	327575	2886	9166	313757
# AGTCCT	334501	3346	10528	318886
# AGTTAC	415022	1894	13886	397191
# ATAACC	258385	2370	9470	245251
# ATCGCA	356406	1468	11125	341774
# ATCTCG	380956	1574	10099	366976
# ATGGAG	292753	2521	8999	279681
# ATGTCC	426271	2121	13237	408823
# CAATTG	713931	32298	17364	660592
# CAGAGT	670359	2888	16189	647624
# CATCAG	566010	5730	16122	541258
# CATCTC	605361	1932	15389	584655
# ...

# %% [markdown]
# ## Move the newly created tsvs to the laptop with fetch
# and import them into the database using the read_to_db.Rmd script in the methods repository.
# *As of 2018-10-06, cannot download them directly from the home tab in the browser*

# %% [markdown]
# ## Rename the sample files
# * used script in seq_proc.Rmd to generate mass command line text stored in SEQXX_all_rename.sh
# * the generation of the original naming files had an extra .F in it, so all of these names are APCL_LXXXX.F.F.fq.gz

# %%
# %%bash
# cd 01Pool/
# sh rename.for.dDocent_se_gz ../logs/names_103.tsv
# mv APCL* ../samples/
# cd ..
# cd 02Pool/
# sh rename.for.dDocent_se_gz ../logs/names_104.tsv
# mv APCL* ../samples/
# cd ..
# cd 03Pool/
# sh rename.for.dDocent_se_gz ../logs/names_107.tsv
# mv APCL* ../samples/
# cd ..
# cd 04Pool/
# sh rename.for.dDocent_se_gz ../logs/names_108.tsv
# mv APCL* ../samples/
# cd ..
# cd 05Pool/
# sh rename.for.dDocent_se_gz ../logs/names_109.tsv
# mv APCL* ../samples/
# cd ..
# cd 06Pool/
# sh rename.for.dDocent_se_gz ../logs/names_110.tsv
# mv APCL* ../samples/
# cd ..
# cd 07Pool/
# sh rename.for.dDocent_se_gz ../logs/names_111.tsv
# mv APCL* ../samples/
# cd ..
# cd 08Pool/
# sh rename.for.dDocent_se_gz ../logs/names_112.tsv
# mv APCL* ../samples/
# cd ..
# cd 09Pool/
# sh rename.for.dDocent_se_gz ../logs/names_113.tsv
# mv APCL* ../samples/
# cd ..
# cd 10Pool/
# sh rename.for.dDocent_se_gz ../logs/names_114.tsv
# mv APCL* ../samples/
# cd ..
# cd 11Pool/
# sh rename.for.dDocent_se_gz ../logs/names_115.tsv
# mv APCL* ../samples/
# cd ..
# cd 12Pool/
# sh rename.for.dDocent_se_gz ../logs/names_116.tsv
# mv APCL* ../samples/
# Out:
# APCL_L3352.F
# AAACAC
# APCL_L3400.F
# AAACAC
# APCL_L3544.F
# AAACAC
# APCL_L3592.F
# AAACAC
# APCL_L3640.F
# AAACAC
# APCL_L3784.F
# AAACAC
# APCL_L3832.F
# AAACAC
# APCL_L3880.F
# AAACAC
# APCL_L3928.F
# AAACAC
# APCL_L3976.F
# AAACAC
# APCL_L4024.F
# AAACAC
# APCL_L4072.F
# AAACAC

# %% [markdown]
# ## Delete the pool directories

# %%
# !rm -r *Pool

# %% [markdown]
# ## Identify regenotyped samples, cat and move them.

# %%
# !mkdir /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos
# Out:
# mkdir: cannot create directory `/local/home/michelles/02-apcl-ddocent/30seq/samples/regenos': File exists

# %% [markdown]
# ### Make a table of all of the regenotyped samples
# * in the R notebook cat_regenos.Rmd.
# * in text editor, find and replace the files coming from seq30 to include the extra F in the names, used the regex
# find: (30seq/samples/APCL_L\d+)(.F).fq.gz
# replace: \1\2.F.fq.gz
# * Changed the R script so that the output file is named in dDocent format and the cat'd output file is kept with the current seq sample population.
# * Generate command lines to paste here.

# %%
# %%bash
# cat /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3119.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3589.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3119.L3589.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/12seq/samples/APCL_L2324.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3400.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2324.L3400.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/03seq/samples/APCL_L0306.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3598.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L0306.L3598.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/03seq/samples/APCL_L0308.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3599.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L0308.L3599.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/03seq/samples/APCL_L0309.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3601.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L0309.L3601.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/08seq/samples/APCL_L1188.F.fq.gz /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3266.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3352.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L1188.L3266.L3352.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2513.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3600.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2513.L3600.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/08seq/samples/APCL_L1297.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3596.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L1297.L3596.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/12seq/samples/APCL_L2351.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3604.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2351.L3604.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2502.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3595.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2502.L3595.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2514.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3594.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2514.L3594.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2503.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3593.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2503.L3593.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2515.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3592.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2515.L3592.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2516.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3591.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2516.L3591.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2504.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3626.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2504.L3626.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2505.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3633.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L2505.L3633.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3170.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3643.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3170.L3643.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/04seq/samples/APCL_L0814.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3644.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L0814.L3644.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3106.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3597.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3106.L3597.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3152.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3588.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3152.L3588.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3146.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3602.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3146.L3602.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3264.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3436.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3264.L3436.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3263.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3437.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3263.L3437.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3260.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3438.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3260.L3438.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3254.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3439.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3254.L3439.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3253.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3440.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3253.L3440.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3247.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3441.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3247.L3441.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3246.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3442.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3246.L3442.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3244.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3443.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3244.L3443.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3243.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3444.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3243.L3444.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3242.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3445.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3242.L3445.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3241.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3446.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3241.L3446.F.fq.gz
# cat /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3240.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3447.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3240.L3447.F.fq.gz
# Out:
# cat: /local/home/michelles/02-apcl-ddocent/08seq/samples/APCL_L1188.F.fq.gz: No such file or directory
# cat: /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3266.F.fq.gz: No such file or directory

# %%
cat /local/home/michelles/02-apcl-ddocent/08seq/samples/regenos/APCL_L1188.F.fq.gz /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/APCL_L3266.F.fq.gz /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3352.F.F.fq.gz > /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L1188.L3266.L3352.F.fq.gz

# %% [markdown]
# ## Move the cat'd files out of their sample populations
# * The cat_regenos.Rmd script in the methods repository generates command lines for this at the bottom of the script

# %%
# %%bash
# mv /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3119* /local/home/michelles/02-apcl-ddocent/17seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3589* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/12seq/samples/APCL_L2324* /local/home/michelles/02-apcl-ddocent/12seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3400* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/03seq/samples/APCL_L0306* /local/home/michelles/02-apcl-ddocent/03seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3598* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/03seq/samples/APCL_L0308* /local/home/michelles/02-apcl-ddocent/03seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3599* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/03seq/samples/APCL_L0309* /local/home/michelles/02-apcl-ddocent/03seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3601* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/08seq/samples/APCL_L1188* /local/home/michelles/02-apcl-ddocent/08seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3266* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3352* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2513* /local/home/michelles/02-apcl-ddocent/13seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3600* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/08seq/samples/APCL_L1297* /local/home/michelles/02-apcl-ddocent/08seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3596* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/12seq/samples/APCL_L2351* /local/home/michelles/02-apcl-ddocent/12seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3604* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2502* /local/home/michelles/02-apcl-ddocent/13seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3595* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2514* /local/home/michelles/02-apcl-ddocent/13seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3594* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2503* /local/home/michelles/02-apcl-ddocent/13seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3593* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2515* /local/home/michelles/02-apcl-ddocent/13seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3592* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2516* /local/home/michelles/02-apcl-ddocent/13seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3591* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2504* /local/home/michelles/02-apcl-ddocent/13seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3626* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/13seq/samples/APCL_L2505* /local/home/michelles/02-apcl-ddocent/13seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3633* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3170* /local/home/michelles/02-apcl-ddocent/17seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3643* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/04seq/samples/APCL_L0814* /local/home/michelles/02-apcl-ddocent/04seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3644* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3106* /local/home/michelles/02-apcl-ddocent/17seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3597* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3152* /local/home/michelles/02-apcl-ddocent/17seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3588* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/17seq/samples/APCL_L3146* /local/home/michelles/02-apcl-ddocent/17seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3602* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3264* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3436* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3263* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3437* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3260* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3438* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3254* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3439* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3253* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3440* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3247* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3441* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3246* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3442* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3244* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3443* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3243* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3444* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3242* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3445* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3241* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3446* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3240* /local/home/michelles/02-apcl-ddocent/28seq/samples/regenos/
# mv /local/home/michelles/02-apcl-ddocent/30seq/samples/APCL_L3447* /local/home/michelles/02-apcl-ddocent/30seq/samples/regenos/
# Out:
# mv: cannot stat `/local/home/michelles/02-apcl-ddocent/08seq/samples/APCL_L1188*': No such file or directory
# mv: cannot stat `/local/home/michelles/02-apcl-ddocent/28seq/samples/APCL_L3266*': No such file or directory

# %% [markdown]
# The error message above is because those files are alread in their regenos directories and do not need to be moved.

# %% [markdown]
# ## Copy reference.fasta over from jonsfiles

# %%
% cp /local/home/michelles/02-apcl-ddocent/jonsfiles/reference.fasta /local/home/michelles/02-apcl-ddocent/30seq/samples/

# %% [markdown]
# ## Trim, map and call SNPs using dDocent in the samples directory
# * Have to do this from terminal because the jupyter notebook does not allow user input mid-script, which dDocent reqires.
# * Running here to generate error so you can see version, date, time.

# %%
# !cd ./samples
# !dDocent
# Out:
# dDocent 2.5.5
#
# Contact jpuritz@uri.edu with any problems
#
#
# Checking for required software
# /local/home/michelles/14_programs/dDocent/dDocent: line 84: [: 1.0-r82: integer expression expected
#
# All required software is installed!
#
# dDocent run started Sat Oct 6 10:31:52 EDT 2018
#
# 0 individuals are detected. Is this correct? Enter yes or no and press [ENTER]

# %% [markdown]
# ## Can view the dDocent.log to see number of individuals and parameters entered to begin run.

# %% [markdown]
# ## Switch to notebook all_samples_filtering for next steps.
